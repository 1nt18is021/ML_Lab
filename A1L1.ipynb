# %%
a=5
print(a)

# %%
a="aishwarya"
a

# %%
a=10
if(a>5):
    greater than 5
else:
    less than 5

# %%
a=10
if(a>5):
    print("greater than 5")
else:
    print("less than 5")

# %%
a=int(input("enter 1st num"))
b=int(input("enter 2nd num"))
ch=input("enter the operator")
if(ch=="+"):
    print(a+b)
elif(ch=="-"):
    print(a-b)
elif(ch=="*"):
    print(a*b)
elif(ch=="/"):
    print(a/b)

# %%
n=int(input())
sum=0
for i in range[0,n]:
    sum+=i
print(sum)

# %%
n=int(input())
sum=0
for i in range(0,n):
    sum+=i
print(sum)

# %%
a="aishwarya"
b=slice(a[0:2])
b

# %%
a="aishwarya"
b=a[0:2]
b

# %%
n=int(input())
sum=0
for i in range(0,n):
    sum+=i
print(sum)

# %%
n=input()
i=0
while(n[i]=)

# %%
l=[10,20,"hello",1.34]
for e in l:
    print(e)

# %%
l=[10,20,"hello",1.34]
l.append(40)
len(l)
l.remove(20)
l.pop()
l.pop(2)
l2=["hello","hi",20]
l1+l2

# %%
l=[10,20,"hello",1.34]
l.append(40)
len(l)
l.remove(20)
l.pop()
l.pop(2)
l2=["hello","hi",20]
l+l2

# %%
l=[10,20,"hello",1.34]
l.append(40)
print(l)
print(len(l))
l.remove(20)
print(l)
print(l.pop())
print(l)
print(l.pop(2))
l2=["hello","hi",20]
l+l2

# %%
n=input()
i=0
ch=""
while(n[i]!=" "):
    ch+=n[i]
print(ch)

# %%
n=input()
i=0
ch=""
while(n[i]!=" "):
    ch+=n[i]
print(ch)

# %%
n=input()
i=0
print(n[i])

# %%
n=input()
i=0
print(n)

# %%
n=input()
i=0
print(n)

# %%
n=input()
i=0
print(n)
# Out:
# HELLO
# HELLO

# %%
n=input()
l=n.split(" ")

print(ch)
# Out:
# 10 + 4
# 10

# %%
l=[1,45,2,6,1,7,8]
sum=0
for e in :
    sum+=e
m=sum/(len(l))
print(m)
# Out:
#   File "<ipython-input-3-b6d1ab31f17e>", line 3
#     for e in :
#              ^
# SyntaxError: invalid syntax

# %%
l=[1,45,2,6,1,7,8]
sum=0
for e in l:
    sum+=e
m=sum/(len(l))
print(m)
# Out:
# 10.0

# %%
l=[1,4,2,6,1,7,8]
sum=0
for e in l:
    sum+=e
m=sum/(len(l))
print(m)
# Out:
# 4.142857142857143

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len%2==0):
    m=(l(len(l)/2)+(l(len(l)/2)+1))/2
    m
else:
    print(l((len(l)+1)/2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cb07695e2400> in <module>
#       1 l=[1,4,2,6,1,7,8]
#       2 l.sort()
# ----> 3 if(len%2==0):
#       4     m=(l(len(l)/2)+(l(len(l)/2)+1))/2
#       5     m
#
# TypeError: unsupported operand type(s) for %: 'builtin_function_or_method' and 'int'

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len mod 2==0):
    m=(l(len(l)/2)+(l(len(l)/2)+1))/2
    m
else:
    print(l((len(l)+1)/2))
# Out:
#   File "<ipython-input-7-7aa3f42acbe1>", line 3
#     if(len mod 2==0):
#            ^
# SyntaxError: invalid syntax

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len(l)%2==0):
    m=(l(len(l)/2)+(l(len(l)/2)+1))/2
    m
else:
    print(l((len(l)+1)/2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-08c5bce4a30a> in <module>
#       5     m
#       6 else:
# ----> 7     print(l((len(l)+1)/2))
#
# TypeError: 'list' object is not callable

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len(l)%2==0):
    m=(l[len(l)/2]+(l[(len(l)/2)+1])/2
    m
else:
    print(l[(len(l)+1)/2])
# Out:
#   File "<ipython-input-9-1f013eae4cd4>", line 5
#     m
#     ^
# SyntaxError: invalid syntax

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len(l)%2==0):
    m=(l[len(l)/2]+(l[(len(l)/2)+1])/2
    print(m)
else:
    print(l[(len(l)+1)/2])
# Out:
#   File "<ipython-input-10-00a8c3785f40>", line 5
#     print(m)
#     ^
# SyntaxError: invalid syntax

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len(l)%2==0):
    m=(l[len(l)/2]+(l[(len(l)/2)+1]))/2
    print(m)
else:
    print(l[(len(l)+1)/2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9064e900f1a4> in <module>
#       5     print(m)
#       6 else:
# ----> 7     print(l[(len(l)+1)/2])
#
# TypeError: list indices must be integers or slices, not float

# %%
l=[1,4,2,6,1,7,8]
l.sort()
if(len(l)%2==0):
    n=len(l)/2
    m=(l[n]+l[n+1])/2
    print(m)
else:
    n=(len(l)+1)/2
    print(l[n])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ce1dd46bb08b> in <module>
#       7 else:
#       8     n=(len(l)+1)/2
# ----> 9     print(l[n])
#
# TypeError: list indices must be integers or slices, not float

# %%
l=[1,4,2,6,1,7,8]
l.sort()
print(l)
if(len(l)%2==0):
    n=len(l)/2
    m=(l[n]+l[n+1])/2
    print(m)
else:
    n=int((len(l)-1)/2)
    print(l[n])
# Out:
# [1, 1, 2, 4, 6, 7, 8]
# 4

# %% [markdown]
#  l=[1,4,2,6,1,7,8]
# for i in range(len(l))

# %%
l=[1,4,2,6,1,7,8]
l.sort()
print(l)
if(len(l)%2==0):
    n=len(l)/2
    m=(l[n]+l[n+1])/2
    print(m)
else:
    n=int((len(l)-1)/2)
    print(l[n])
# Out:
# [1, 1, 2, 4, 6, 7, 8]
# 4
